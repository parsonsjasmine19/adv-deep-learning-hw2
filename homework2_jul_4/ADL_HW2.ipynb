# %%
# !git clone https://github.com/parsonsjasmine19/adv-deep-learning-hw2.git
# %cd adv-deep-learning-hw2/homework2_jul_4
# Out:
# Cloning into 'adv-deep-learning-hw2'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 33 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 1.54 MiB | 19.51 MiB/s, done.
# /content/adv-deep-learning-hw2/homework2_jul_4

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 74.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 46.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 47.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.5.1 which is incompatible.
# ...

# %%
import os
if not os.path.exists('data'):
    # !wget https://utexas.box.com/shared/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip -O supertux_data.zip
    # !unzip -q supertux_data.zip
# Out:
# --2026-07-08 01:24:14--  https://utexas.box.com/shared/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip
# Resolving utexas.box.com (utexas.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to utexas.box.com (utexas.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip [following]
# --2026-07-08 01:24:14--  https://utexas.box.com/public/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip
# Reusing existing connection to utexas.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://utexas.app.box.com/public/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip [following]
# --2026-07-08 01:24:14--  https://utexas.app.box.com/public/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip
# Resolving utexas.app.box.com (utexas.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# ...

# %% [markdown]
# ## Training

# %%
# !python3 -m homework.train PatchAutoEncoder
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/adv-deep-learning-hw2/homework2_jul_4/homework/train.py", line 150, in <module>
#     Fire(train)
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 135, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 468, in _Fire
#     component, remaining_args = _CallAndUpdateTrace(
#                                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 684, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/adv-deep-learning-hw2/homework2_jul_4/homework/train.py", line 127, in train
# ...

# %%
# !python3 -m homework.train BSQPatchAutoEncoder
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/adv-deep-learning-hw2/homework2_jul_4/homework/train.py", line 150, in <module>
#     Fire(train)
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 135, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 468, in _Fire
#     component, remaining_args = _CallAndUpdateTrace(
#                                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 684, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/adv-deep-learning-hw2/homework2_jul_4/homework/train.py", line 127, in train
# ...

# %%
import glob
bsq_ckpt = sorted(glob.glob('checkpoints/*_BSQPatchAutoEncoder.pth'))[-1]
# !python3 -m homework.tokenize {bsq_ckpt} data/tokenized_train.pth data/train/
# !python3 -m homework.tokenize {bsq_ckpt} data/tokenized_valid.pth data/valid/
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_936/2643282885.py in <cell line: 0>()
#       1 import glob
# ----> 2 bsq_ckpt = sorted(glob.glob('checkpoints/*_BSQPatchAutoEncoder.pth'))[-1]
#       3 get_ipython().system('python3 -m homework.tokenize {bsq_ckpt} data/tokenized_train.pth data/train/')
#       4 get_ipython().system('python3 -m homework.tokenize {bsq_ckpt} data/tokenized_valid.pth data/valid/')
#
# IndexError: list index out of range

# %%
# !python3 -m homework.train AutoregressiveModel
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/adv-deep-learning-hw2/homework2_jul_4/homework/train.py", line 150, in <module>
#     Fire(train)
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 135, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 468, in _Fire
#     component, remaining_args = _CallAndUpdateTrace(
#                                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 684, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/adv-deep-learning-hw2/homework2_jul_4/homework/train.py", line 129, in train
# ...

# %% [markdown]
# ## Grade

# %%
# !python3 -m grader -vv homework
# Out:
# Val grader loaded.
# [DEBUG    00:00:000] Loading assignment
# [DEBUG    00:00:017] Loading grader
# [INFO     00:00:018] Patch AutoEncoder
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# [DEBUG    00:00:034] Loading PatchAutoEncoder from /content/adv-deep-learning-hw2/homework2_jul_4/homework/PatchAutoEncoder.pth
# [WARNING  00:00:038]   - Image Reconstruction MSE Loss                      [ 0 / 30 FileNotFoundError ]
# [ERROR    00:00:038] Traceback (most recent call last):
# ...

# %% [markdown]
# ## Bundle and download

# %%
UT_ID = 'my_ut_id'  # change this
# !python3 bundle.py homework {UT_ID}
# !python3 -m grader {UT_ID}.zip

# %%
from google.colab import files
files.download(f'{UT_ID}.zip')
